# %% [markdown]
# # Title: The Beginning of Coding
#
# ## The Basics: Beginning to Use Microsoft Copilot
#
# Goals:
# - Learning basic programming concepts.
# - I want to gain knowledge and have ease with understanding the programming language.

# %% [markdown]
# Hello, World!
#
# The following code was created as my first attempt at programming in this course. In the process of learning and understanding how to write and run code in GitHub Codespaces.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Understanding Microsoft Copilot: Series of Prompts

# %% [markdown]
# Printing. Could you suggest a python
# code for ‘Hello, world!’ to demonstrate the concept of printing to a
# complete beginner in programming? Please explain the code step-by-step
# highlighting any key aspects.
#
# Key learning outcomes:- AI copilot provides a clear answer, It gave me a simple answer compared to the one given in the lab notes however, it always gives the bais and main information.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
message = "Hello, world!"

# %%
print(message)
# Out:
# Hello, world!

# %% [markdown]
# #### Copilots Response:

# %% [markdown]
# #### Variables

# %%
# Hello, world! using variables 
# greeting = "Hello" 
# target = "world" 
# punctuation = "!" 
# message = greeting + ", " + target + punctuation 
# print(message)

# %% [markdown]
# Copilots explanations to why use varibales
#
# - Reuse values multiple times
# - update values easily
# - make your code more readable and oragnised
#
#
# learning outcomes:-
# - having a way to allow code to become more organsied and reusable allows for a faster coding process

# %% [markdown]
# #### Functions:

# %%
# Hello, world! with a function 
def make_message(greeting, target): 
    return f"{greeting}, {target}!" 
message = make_message("Hello", "world") 
print(message)
# Out:
# Hello, world!

# %% [markdown]
# - Copilot has presented a step-by-step explanation to the code, explaning each step and the reason to using it.
#
# example = Calling the function: make_message("Hello,","world") runs the function with specific arguments.

# %% [markdown]
# #### Loops

# %%
# Hello, world! repeated with a loop
times = 3

for i in range(times):
    print(f"Hello, world! ({i + 1})")
# Out:
# Hello, world! (1)
# Hello, world! (2)
# Hello, world! (3)

# %% [markdown]
# - the reason for using loops is that it allows for ease when coding, removes the need for duplicating code.

# %% [markdown]
# #### Lists

# %%
def greet(name):
    print("Hello, " + name + "!")

greet("Alice")
greet("Bob")
# Out:
# Hello, Alice!
# Hello, Bob!

# %% [markdown]
# - makes it so that lists ae not needed to be a tedious action, greeting multiple people requires a simple note of their name.
#
# - copilot helps to breakdown each part and why its used, as noted in the defintions in 'def' 'greet' '()' ':' and so on. This allows for a deeper understanding of why youre writing the code and truly understanding it.
#
# - Copilot explains that the list size can grow or shrink, for example, adding names.ppend("Charlie"), or names.remove("Bob). Showcasing use of the code.

# %% [markdown]
# #### Dictionaries

# %%
# Personalized greetings using a dictionary
greetings = {
    "world": "Hello",
    "Alice": "Hi",
    "Bob": "Hey"
}

for name, greeting in greetings.items():
    print(f"{greeting}, {name}!")
# Out:
# Hello, world!
# Hi, Alice!
# Hey, Bob!

# %% [markdown]
# - This is a collection of key-value pairs, keys must be unique.
# - The importance of dictionaries include the speed, the code allows looking up items to become an easy task, finding items through a list is made easy.
# - The use of values allows for data to become self-describing, creating clear messaging.

# %% [markdown]
# #### Arrays

# %%
# Using array from the standard library for numbers
from array import array

counts = array("i", [1, 2, 3])  # "i" means signed integer
for c in counts:
    print(f"Hello, world! x{c}")
# Out:
# Hello, world! x1
# Hello, world! x2
# Hello, world! x3

# %% [markdown]
# - Copilot helps to explain the difference between using Arrays instead of Lists,
#     - Lists can hold mixed typed, arrays hold ine fixed numeric type and can be more memory-efficient.
#
# - This allows it to be beneficial when dealing with large numeric data, while begginers usually start with lists.

# %% [markdown]
# #### Importing Libraries

# %%
# Using the math library to format Hello, world! with a number
import math

times = math.ceil(2.4)  # rounds up to 3
for i in range(times):
    print(f"Hello, world! ({i + 1})")
# Out:
# Hello, world! (1)
# Hello, world! (2)
# Hello, world! (3)

# %% [markdown]
# Copilot response:
# - Import statement:
# import math brings external functionality into your program.
#
# Using library functions:
# - math.ceil(2.4) uses the library to round up.
#
# Namespace:
# - Call as math.function() unless you use from math import ceil.
#
# Why import:
# - Libraries help solve common tasks without reinventing the wheel.

# %% [markdown]
# #### Conditionals (if, elif, else)

# %%
# Hello with different messages based on time of day
time_of_day = "morning"  # try "afternoon" or "evening"

if time_of_day == "morning":
    print("Good morning, world!")
elif time_of_day == "afternoon":
    print("Good afternoon, world!")
else:
    print("Good evening, world!")
# Out:
# Good morning, world!

# %% [markdown]
# - Learning that this code runs code when a condition is true (if), this creates clear conditions, making prorams easier to understand.

# %% [markdown]
# #### Operators

# %%
# Arithmetic and string operations
a = 2 + 3          # 5
b = 4 * 2          # 8
text = "Hello" + " " + "world"  # "Hello world"
echo = "ha" * 3    # "hahaha"

# Mixing types carefully
number = 5
word = " times"
# print(number + word)  # TypeError: cannot add int and str
print(str(number) + word)  # "5 times"
# Out:
# 5 times

# %% [markdown]
# #### Classes, objects, and methods

# %%
# A simple Greeter class
class Greeter:
    def __init__(self, greeting):
        self.greeting = greeting  # instance attribute

    def greet(self, target):
        return f"{self.greeting}, {target}!"

greeter = Greeter("Hello")   # create an object
print(greeter.greet("world"))
# Out:
# Hello, world!

# %% [markdown]
# #### Basic Python syntax and style

# %%
# Clean, styled Hello, world!
def main():
    greeting = "Hello"
    target = "world"
    print(f"{greeting}, {target}!")

if __name__ == "__main__":
    main()
# Out:
# Hello, world!

# %%
temperature = 25

if temperature > 20:
    print("It's warm outside!")
# Out:
# It's warm outside!

# %%
for i in range(3):
    print("Hello!")
# Out:
# Hello!
# Hello!
# Hello!

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[1])
# Out:
# banana

# %% [markdown]
# Benefits of using Copilot for learning Python:-
# - Instant feedback: the code is given step by step if the prompt sattes it, the AI will describe what to do and why to do it, deepening your understanding of the process. If its not extensive enough, follow up questions can be easily asked to clear up any misunderstandings.
#
# - Beginner-friendly: the step-by-step is usually understandable and clear.
#
# - customisable: follow up questions and add ons can be added after the initial prompt.
#
# - creative support: builds projects, explore ideas, and debug code. It can assist the individual with anything.

# %% [markdown]
# Limitations:-
#
# - no hands-on practice: AI allows for guidance, not self study, coding yourself to get practice completing it by yourself is crucial to fully grasp the skill and learn.
#
# - limited context: AI cannot see the entire learning history
#
# - not a substitute for structured learning - books, courses, and mentors offer a deeper theory and long-term guidance. The information will retain better with further guidance and practice.
#
# - may oversimplify: deeper nuances are skipped

# %% [markdown]
# # Algorithms, Pseudocode, and Python Code
#
# ## 1. My everyday Algorithms
#
# - making tea
#
# This everyday routine can be written as an algorithm because it follows a sequence of steps.
#
#
# ### *example 1*

# %%
import string
from collections import Counter

# Poem text 
poem = """
Boil water
Place teabag in mug
Wait 2 Minutes
Remove teabag
Add milk if desired
Output tea

"""

# Step 1: Normalize and split text into words
words = [w.lower().strip(string.punctuation) for w in poem.split()]

# Step 2: Count word frequencies
counts = Counter(words)

# Step 3: Find the most frequent word
most_common = counts.most_common(1)[0]

# Step 4: Output result
print("Most frequent word:", most_common[0], "appears", most_common[1], "times")
# Out:
# Most frequent word: teabag appears 2 times

# %% [markdown]
# I asked the copilot to fix the code due to me having an error, It fixed it by adding the beginner text (import string..), Microsoft Copilot fixed my code for me. It responded how I expected it to respond, by giving the answer and a small description of the fixes and improvements.

# %% [markdown]
# ### *example 2*

# %%
import string
from collections import Counter

# Poem text
poem = """
Whose woods these are I think I know.
His house is in the village though;
He will not see me stopping here
To watch his woods fill up with snow.
My little horse must think it queer
To stop without a farmhouse near
Between the woods and frozen lake
The darkest evening of the year.
He gives his harness bells a shake
To ask if there is some mistake.
The only other sound’s the sweep
Of easy wind and downy flake.
The woods are lovely, dark and deep,
But I have promises to keep,
And miles to go before I sleep,
And miles to go before I sleep.
"""

# Step 1: Normalize and split text into words
words = [w.lower().strip(string.punctuation) for w in poem.split()]

# Step 2: Count word frequencies
counts = Counter(words)

# Step 3: Find the most frequent word
most_common = counts.most_common(1)[0]

# Step 4: Output result
print("Most frequent word:", most_common[0], "appears", most_common[1], "times")
# Out:
# Most frequent word: the appears 7 times

# %% [markdown]
# # Python Libraries - Importing Video

# %%
from IPython.display import *

# %%
YouTubeVideo("?v=dVYl5ImNjow&list=PL4Gr5tOAPttLOY9IrWVjJlv4CtkYI5cI_&index=13")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/?v=dVYl5ImNjow&list=PL4Gr5tOAPttLOY9IrWVjJlv4CtkYI5cI_&index=13"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Understanding a Program: Parsing and Reading

# %%
import webbrowser
import requests

print("Shall we hunt down an old website?")

site = input("Type a website URL: ")

era = input("Type year, month, and date, e.g., 20150613: ")

url = "http://archive.org/wayback/available?url=%s&timestamp=%s" % (site, era)


response = requests.get(url)
data = response.json()

try:
    old_site = data["archived_snapshots"]["closest"]["url"]
    print("Found this copy:", old_site)
    print("It should appear in your browser.")
    webbrowser.open(old_site)
except:
    print("Sorry, could not find the site.")
# Out:
# Shall we hunt down an old website?
# Found this copy: http://web.archive.org/web/20120405000030/http://www.youtube.com/
# It should appear in your browser.

# %% [markdown]
# # IPython.display: images and audio

# %%
IPython.display import Image

Image("picture.jpg”)

IPython.display import Audio

Audio(”audio1.mid”)

IPython.display import Audio

Audio(”audio2.ogg”)
# Out:
#   Cell In[1], line 3
#     Image("picture.jpg”)
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %% [markdown]
# #### Reflection:
# #audio2.ogg is owned by Artuffuge Mahmet Okonsar
#
# #audio2.ogg: This file is licensed under the Creative Commons Attribution-Share Alike 3.0 Unported license
#
# You are free:
#
# - to share - to copy, distribute and transmit the work
# - to remix - to adapt the work
#
# Under the following conditions:
#
# - attribution - You must give appropriate credit, provide a link to the license, and indicate if changes were made. You may do so in any reasonable manner, but not in any way that suggests the licensor endorses you or your use.
# - share alike - If you remix, transform, or build upon the material, you must distribute your contributions under the same or compatible license as the original.
#
# The original ogg file was found at the url:
#
# https://en.wikipedia.org/wiki/File:GoldbergVariations_MehmetOkonsar-1of3_Var1to10.ogg
#
# - This audio file has not been remixed, it is in its original state, using it in the aims of learning the basics of GitHub tools and coding processes.

# %%
from IPython.display import Image

# Display the picture
Image("picture1.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/IPython/core/display.py:1100, in Image._data_and_metadata(self, always_both)
#    1099 try:
# -> 1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# ...

# %%
from IPython.display import Audio

# Play the first audio file
Audio("audio1.mp4")

# Play the second audio file
Audio("audio2.mp4")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       1 from IPython.display import Audio
#       3 # Play the first audio file
# ----> 4 Audio("audio1.mp4")
#       6 # Play the second audio file
#       7 Audio("audio2.mp4")
#
# File ~/.local/lib/python3.12/site-packages/IPython/lib/display.py:129, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     127 if self.data is not None and not isinstance(self.data, bytes):
#     128     if rate is None:
# --> 129         raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     130     self.data = Audio._make_wav(data, rate, normalize)
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %%
from matplotlib import pyplot
test_picture=pyplot.imread("picture1.jpg”)
print(”Numpy array of the image is:”,test_picture)
pyplot.imshow(test_picture)
# Out:
#   Cell In[8], line 2
#     test_picture=pyplot.imread("picture1.jpg”)
#                                ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
from matplotlib import pyplot

# %% [markdown]
# # Large Language Models

# %% [markdown]
# #### Overview
#
# Title: "StoryCraft: Interactive Narratives"
#
# Purpose: To create an interactive platfrom where players use a large language model (LLM) to co-create game worls, quests, and characters, maps, and much more.
#
# The application leverages LLMs to:
# - Generated dynamic storytelling tailored to player choices.
# - Alter the established game narratives to incorporate marginalised voices and viewpoints.
# - Provide educational and cultural layers intot the gameplay, for example, historical context and mythological references).
# - Encourage innovation by allowing players to collaborate with the AI on quests, encourage communications,and mythology.
#
#
# ### Processing
#
# - The LLM predicts dialogue and narrative responses based on:
#         - Language patterns learned during training
#         - prompt instructions that enforce tone, hisotrical context, and ethical boundaries.
#
#
# ##### Critical Reflection: Social & Cultural Implications
#
# The LLM encourage representation, engagament, and education. However, the challenges must be mentioned.
#
# ###### Challenges:
#
# - Ownership - the question of who owns the game, due to it being a co-created story game, between the players and AI, there may be a grey area for the ownership.
# - Bias in training data - LLMs may reproduce stereotypes unless carefully guided
# - Authenticity when it comes to the cultural references must be looked upon, cultures must be respected and not tokanised within the story game.
